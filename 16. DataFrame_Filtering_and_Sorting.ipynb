# %% [markdown]
# <a href="https://colab.research.google.com/github/Aidi379/Python_fundamental/blob/main/16.%20DataFrame_Filtering_and_Sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas is a data manipulation and analysis tool that uses a data structure known as DataFrame.
# DataFrames empower programmers to store and manipulate data in a tabular fashion (rows & columns).
# Import Pandas Library into the current environment
# "pd" is an alias of "Pandas"
import pandas as pd

# %%
# Pandas is used to read a csv file and store data in a DataFrame
from google.colab import files
uploaded = files.upload()
investor_df = pd.read_csv('investors_data.csv')
investor_df
# Out:
#      <input type="file" id="files-d55c0e85-3486-4703-bf99-ac1549136a09" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d55c0e85-3486-4703-bf99-ac1549136a09">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Select Loyal clients who have been with the investment firm for at least 15 years
loyal_df = investor_df[ investor_df['Years with Investment Firm'] >=15  ]
loyal_df
# Out:
#   First Name Last Name  Age  Portfolio Size  Years with Investment Firm  \
# 1     Sherif    George   54        950000.0                        30.0
# 5     Bassel      Nasr   50        401201.0                        15.0
# 7      Nancy     Smith   55        900000.0                        17.0
#
#   Risk Tolerance    Goal
# 1   conservative  retire
# 5   conservative  retire
# 7   conservative  retire

# %%
# You might need to reset the index for the new Pandas DataFrame
loyal_df.reset_index(inplace = True)
loyal_df
# Out:
#    index First Name Last Name  Age  Portfolio Size  \
# 0      1     Sherif    George   54        950000.0
# 1      5     Bassel      Nasr   50        401201.0
# 2      7      Nancy     Smith   55        900000.0
#
#    Years with Investment Firm Risk Tolerance    Goal
# 0                        30.0   conservative  retire
# 1                        15.0   conservative  retire
# 2                        17.0   conservative  retire

# %%
# You can sort the values in the dataframe according to the portfolio size
investor_df.sort_values(by = 'Portfolio Size')
# Out:
#   First Name  Last Name  Age  Portfolio Size  Years with Investment Firm  \
# 8      Heidi      Smith   23          1500.0                         1.0
# 4      Sarah        Aly   26         41258.0                         2.0
# 0       Ryan      David   32         80100.0                         5.0
# 2     Sandra  Stevenson   40        150509.0                        10.0
# 3   Victoria     Keller   43        300901.0                         NaN
# 5     Bassel       Nasr   50        401201.0                        15.0
# 7      Nancy      Smith   55        900000.0                        17.0
# 1     Sherif     George   54        950000.0                        30.0
# 6      Chris      Peter   38             NaN                         8.0
#
#   Risk Tolerance                 Goal
# 8       moderate         retire early
# 4     aggressive    pay student loans
# 0     aggressive            buy house
# 2       moderate       kids education
# 3       moderate  investment property
# ...

# %%
# Let's display the Pandas DataFrame again
# Notice that nothing has changed in memory! you have to make sure that inplace is set to True
investor_df
# Out:
#   First Name  Last Name  Age  Portfolio Size  Years with Investment Firm  \
# 0       Ryan      David   32         80100.0                         5.0
# 1     Sherif     George   54        950000.0                        30.0
# 2     Sandra  Stevenson   40        150509.0                        10.0
# 3   Victoria     Keller   43        300901.0                         NaN
# 4      Sarah        Aly   26         41258.0                         2.0
# 5     Bassel       Nasr   50        401201.0                        15.0
# 6      Chris      Peter   38             NaN                         8.0
# 7      Nancy      Smith   55        900000.0                        17.0
# 8      Heidi      Smith   23          1500.0                         1.0
#
#   Risk Tolerance                 Goal
# 0     aggressive            buy house
# 1   conservative               retire
# 2       moderate       kids education
# 3       moderate  investment property
# 4     aggressive    pay student loans
# ...

# %%
# Set inplace = True to ensure that change has taken place in memory
investor_df.sort_values(by = 'Portfolio Size', inplace = True)

# %%
# Note that now the change (ordering) took place
investor_df
# Out:
#   First Name  Last Name  Age  Portfolio Size  Years with Investment Firm  \
# 8      Heidi      Smith   23          1500.0                         1.0
# 4      Sarah        Aly   26         41258.0                         2.0
# 0       Ryan      David   32         80100.0                         5.0
# 2     Sandra  Stevenson   40        150509.0                        10.0
# 3   Victoria     Keller   43        300901.0                         NaN
# 5     Bassel       Nasr   50        401201.0                        15.0
# 7      Nancy      Smith   55        900000.0                        17.0
# 1     Sherif     George   54        950000.0                        30.0
# 6      Chris      Peter   38             NaN                         8.0
#
#   Risk Tolerance                 Goal
# 8       moderate         retire early
# 4     aggressive    pay student loans
# 0     aggressive            buy house
# 2       moderate       kids education
# 3       moderate  investment property
# ...

# %% [markdown]
# **PRACTICE OPPORTUNITY:**
# - **Using Pandas, complete the following tasks:**
#     - **1. Import the "investor_data.csv" using Pandas**
#     - **2. Sort the Pandas DataFrame using the "Age" column from oldest to youngest (in a descending order). Make sure to enforce the change to take place in memory [External Research is Required].**
#     - **3. Leverage pandas operations to only select high networth individuals with minimum portfolio size of $500,000.**
#     - **4. What is the combined portfolio size for all customers with networth of \\$500,000+?**

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
investor_df = pd.read_csv('investors_data.csv')
investor_df
# Out:
#      <input type="file" id="files-ae445e43-8eff-47e1-8535-92981c24460b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae445e43-8eff-47e1-8535-92981c24460b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
investor_df.sort_values(by = 'Age', ascending = False, inplace=True)

# %%
investor_df
# Out:
#   First Name  Last Name  Age  Portfolio Size  Years with Investment Firm  \
# 7      Nancy      Smith   55        900000.0                        17.0
# 1     Sherif     George   54        950000.0                        30.0
# 5     Bassel       Nasr   50        401201.0                        15.0
# 3   Victoria     Keller   43        300901.0                         NaN
# 2     Sandra  Stevenson   40        150509.0                        10.0
# 6      Chris      Peter   38             NaN                         8.0
# 0       Ryan      David   32         80100.0                         5.0
# 4      Sarah        Aly   26         41258.0                         2.0
# 8      Heidi      Smith   23          1500.0                         1.0
#
#   Risk Tolerance                 Goal
# 7   conservative               retire
# 1   conservative               retire
# 5   conservative               retire
# 3       moderate  investment property
# 2       moderate       kids education
# ...

# %%
high_networth_df = investor_df[investor_df['Portfolio Size'] >=500000]

# %%
high_networth_df
# Out:
#   First Name Last Name  Age  Portfolio Size  Years with Investment Firm  \
# 7      Nancy     Smith   55        900000.0                        17.0
# 1     Sherif    George   54        950000.0                        30.0
#
#   Risk Tolerance    Goal
# 7   conservative  retire
# 1   conservative  retire

# %%
high_networth_df['Portfolio Size'].sum()
# Out:
# 1850000.0

# %%
print('the combined portfolio size for all customers with networth of \$500,000+? is ${}'.format(high_networth_df['Portfolio Size'].sum()))
# Out:
# the combined portfolio size for all customers with networth of \$500,000+? is $1850000.0

# %% [markdown]
# # PRACTICE OPPORTUNITY SOLUTION

# %% [markdown]
# **PRACTICE OPPORTUNITY SOLUTION:**
# - **Using Pandas, complete the following tasks:**
#     - **1. Import the "investor_data.csv" using Pandas**
#     - **2. Sort the Pandas DataFrame using the "Age" column from oldest to youngest (in a descending order). Make sure to enforce the change to take place in memory [External Research is Required].**
#     - **3. Leverage pandas operations to only select high networth individuals with minimum portfolio size of $500,000.**
#     - **4. What is the combined portfolio size for all customers with networth of \\$500,000+?**

# %%
# Pandas is used to read a csv file and store data in a DataFrame
investor_df = pd.read_csv('investors_data.csv')
investor_df
# Out:
#   First Name  Last Name  Age  Portfolio Size  Years with Investment Firm  \
# 0       Ryan      David   32         80100.0                         5.0
# 1     Sherif     George   54        950000.0                        30.0
# 2     Sandra  Stevenson   40        150509.0                        10.0
# 3   Victoria     Keller   43        300901.0                         NaN
# 4      Sarah        Aly   26         41258.0                         2.0
# 5     Bassel       Nasr   50        401201.0                        15.0
# 6      Chris      Peter   38             NaN                         8.0
# 7      Nancy      Smith   55        900000.0                        17.0
# 8      Heidi      Smith   23          1500.0                         1.0
#
#   Risk Tolerance                 Goal
# 0     aggressive            buy house
# 1   conservative               retire
# 2       moderate       kids education
# 3       moderate  investment property
# 4     aggressive    pay student loans
# ...

# %%
# Set inplace = True to ensure that change has taken place in memory
investor_df.sort_values(by = 'Age', ascending = False, inplace = True)

# %%
investor_df
# Out:
#   First Name  Last Name  Age  Portfolio Size  Years with Investment Firm  \
# 7      Nancy      Smith   55        900000.0                        17.0
# 1     Sherif     George   54        950000.0                        30.0
# 5     Bassel       Nasr   50        401201.0                        15.0
# 3   Victoria     Keller   43        300901.0                         NaN
# 2     Sandra  Stevenson   40        150509.0                        10.0
# 6      Chris      Peter   38             NaN                         8.0
# 0       Ryan      David   32         80100.0                         5.0
# 4      Sarah        Aly   26         41258.0                         2.0
# 8      Heidi      Smith   23          1500.0                         1.0
#
#   Risk Tolerance                 Goal
# 7   conservative               retire
# 1   conservative               retire
# 5   conservative               retire
# 3       moderate  investment property
# 2       moderate       kids education
# ...

# %%
high_networth_df = investor_df[ investor_df['Portfolio Size'] >= 500000 ]
high_networth_df
# Out:
#   First Name Last Name  Age  Portfolio Size  Years with Investment Firm  \
# 7      Nancy     Smith   55        900000.0                        17.0
# 1     Sherif    George   54        950000.0                        30.0
#
#   Risk Tolerance    Goal
# 7   conservative  retire
# 1   conservative  retire

# %%
print('The combined portfolio size of clients with at least $500,000 is = ${}'.format(high_networth_df['Portfolio Size'].sum()))
# Out:
# The combined portfolio size of clients with at least $500,000 is = $1850000.0

# %% [markdown]
# # EXCELLENT JOB!
